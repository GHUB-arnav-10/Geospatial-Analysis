# %%
import geopandas as gpd

# %%
data=gpd.read_file('/content/DEC_lands.shp')

# %%
data.head()
# Out:
#    OBJECTID          CATEGORY UNIT                          FACILITY  \
# 0         1  FOR PRES DET PAR  CFP        HANCOCK FP DETACHED PARCEL
# 1         2  FOR PRES DET PAR  CFP        HANCOCK FP DETACHED PARCEL
# 2         3  FOR PRES DET PAR  CFP        HANCOCK FP DETACHED PARCEL
# 3         4  FOR PRES DET PAR  CFP  GREENE COUNTY FP DETACHED PARCEL
# 4         6   FOREST PRESERVE  AFP         SARANAC LAKES WILD FOREST
#
#          CLASS            UMP                       DESCRIPTIO  REGION  \
# 0  WILD FOREST           None  DELAWARE COUNTY DETACHED PARCEL       4
# 1  WILD FOREST           None  DELAWARE COUNTY DETACHED PARCEL       4
# 2  WILD FOREST           None  DELAWARE COUNTY DETACHED PARCEL       4
# 3  WILD FOREST           None                             None       4
# 4  WILD FOREST  SARANAC LAKES                             None       5
#
#      COUNTY                                     URL            SOURCE UPDATE_  \
# ...

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
imp_data=data.loc[:,["CLASS","COUNTY","geometry"]].copy()

# %%
imp_data.head()
# Out:
#          CLASS    COUNTY                                           geometry
# 0  WILD FOREST  DELAWARE  POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1  WILD FOREST  DELAWARE  POLYGON ((491931.514 4637416.256, 491305.424 4...
# 2  WILD FOREST  DELAWARE  POLYGON ((486000.287 4635834.453, 485007.550 4...
# 3  WILD FOREST    GREENE  POLYGON ((541716.775 4675243.268, 541217.579 4...
# 4  WILD FOREST     ESSEX  POLYGON ((583896.043 4909643.187, 583891.200 4...

# %%
imp_data.CLASS.value_counts()
# Out:
# CLASS
# WILD FOREST                   965
# INTENSIVE USE                 108
# PRIMITIVE                      60
# WILDERNESS                     52
# ADMINISTRATIVE                 17
# UNCLASSIFIED                    7
# HISTORIC                        5
# PRIMITIVE BICYCLE CORRIDOR      4
# CANOE AREA                      1
# Name: count, dtype: int64

# %%
wild_lands=imp_data.loc[imp_data.CLASS.isin(['WILD FOREST','WILDERNESS'])].copy()
wild_lands.head()
# Out:
#          CLASS    COUNTY                                           geometry
# 0  WILD FOREST  DELAWARE  POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1  WILD FOREST  DELAWARE  POLYGON ((491931.514 4637416.256, 491305.424 4...
# 2  WILD FOREST  DELAWARE  POLYGON ((486000.287 4635834.453, 485007.550 4...
# 3  WILD FOREST    GREENE  POLYGON ((541716.775 4675243.268, 541217.579 4...
# 4  WILD FOREST     ESSEX  POLYGON ((583896.043 4909643.187, 583891.200 4...

# %%
wild_lands.plot()
# Out:
# <Axes: >

# %%
wild_lands.geometry.head()
# Out:
# 0    POLYGON ((486093.245 4635308.586, 486787.235 4...
# 1    POLYGON ((491931.514 4637416.256, 491305.424 4...
# 2    POLYGON ((486000.287 4635834.453, 485007.550 4...
# 3    POLYGON ((541716.775 4675243.268, 541217.579 4...
# 4    POLYGON ((583896.043 4909643.187, 583891.200 4...
# Name: geometry, dtype: geometry

# %%
#POINTS
POI_data=gpd.read_file('/content/Decptsofinterest.shp')
POI_data.head()
# Out:
#    OBJECTID            UNIT                        FACILITY  \
# 0     91706             CFP            DELAWARE WILD FOREST
# 1    108646     SCHUYLER 02         SUGAR HILL STATE FOREST
# 2     19933             AFP  MOOSE RIVER PLAINS WILD FOREST
# 3      3945     ALLEGANY 12        LOST NATION STATE FOREST
# 4      1037  CATTARAUGUS 08          ROCK CITY STATE FOREST
#
#                               NAME                ASSET DESCRIP  REGION  \
# 0           ADA PRIMITIVE CAMPSITE   PRIMITIVE CAMPSITE    None       4
# 1           MAPLE LANE CAMPSITE #3   PRIMITIVE CAMPSITE    None       8
# 2  MOOSE RIVER PLAINS CAMPSITE 103   PRIMITIVE CAMPSITE    LIVE       5
# 3               NEWLAND FR PARKING  UNPAVED PARKING LOT     -99       9
# 4           LRC PICNIC PAVILION #1      PICNIC PAVILION    None       9
#
#         OFFICE     UPDATED  ASSET_UID ACCESSIBLE  \
# 0     STAMFORD  2016-09-26      16519          N
# 1         BATH  2018-02-23      18124          N
# ...

# %%
#SELECTING CAMPSITES
campsites=POI_data.loc[POI_data.ASSET=='PRIMITIVE CAMPSITE'].copy()
campsites.head()
# Out:
#    OBJECTID         UNIT                        FACILITY  \
# 0     91706          CFP            DELAWARE WILD FOREST
# 1    108646  SCHUYLER 02         SUGAR HILL STATE FOREST
# 2     19933          AFP  MOOSE RIVER PLAINS WILD FOREST
# 5     39673          AFP       SARANAC LAKES WILD FOREST
# 6     19434          AFP         LAKE GEORGE WILD FOREST
#
#                                  NAME               ASSET  \
# 0              ADA PRIMITIVE CAMPSITE  PRIMITIVE CAMPSITE
# 1              MAPLE LANE CAMPSITE #3  PRIMITIVE CAMPSITE
# 2     MOOSE RIVER PLAINS CAMPSITE 103  PRIMITIVE CAMPSITE
# 5  SARANAC ISLANDS CAMPGROUND SITE 27  PRIMITIVE CAMPSITE
# 6           GAY POND ROAD CAMPSITE 13  PRIMITIVE CAMPSITE
#
#                                              DESCRIP  REGION       OFFICE  \
# 0                                               None       4     STAMFORD
# 1                                               None       8         BATH
# ...

# %%
#LineString(Foot Trails)
road_trails=gpd.read_file('/content/Decroadstrails.shp')
road_trails.head()
# Out:
#    OBJECTID UNIT                 FACILITY                NAME  \
# 0       208  AFP  FERRIS LAKE WILD FOREST       PHANTOM TRAIL
# 1       211  AFP  FERRIS LAKE WILD FOREST       PHANTOM TRAIL
# 2       212  AFP  FERRIS LAKE WILD FOREST    PARKER VLY TRAIL
# 3       229  AFP  FERRIS LAKE WILD FOREST       WAGONERS LOOP
# 4       233  AFP  FERRIS LAKE WILD FOREST  SHERIFF LAKE TRAIL
#
#               ASSET ATV FOOT HORSE BIKE XC  ... MAPPWD DESCRIP ROAD_CLASS  \
# 0  SNOWMOBILE TRAIL   N    Y     N    N  Y  ...      N    None         RT
# 1  SNOWMOBILE TRAIL   N    Y     N    N  Y  ...      N    None         RT
# 2  SNOWMOBILE TRAIL   N    Y     N    N  Y  ...      N    None         RT
# 3  SNOWMOBILE TRAIL   N    Y     Y    Y  Y  ...      N    None         RT
# 4  SNOWMOBILE TRAIL   N    Y     Y    Y  Y  ...      N    None         RT
#
#       UPDATED REGION      OFFICE MARKER     TRANS_UID     SHAPE_LEN  \
# 0  2011-05-17      5  NORTHVILLE   None   1583.181399   1577.112643
# ...

# %%
#SELECTING FOOT TRAILS
trails = road_trails.loc[road_trails.ASSET=='FOOT TRAIL'].copy()
trails.head()
# Out:
#     OBJECTID UNIT                    FACILITY  \
# 31       304  AFP  DEBAR MOUNTAIN WILD FOREST
# 34       311  AFP  DEBAR MOUNTAIN WILD FOREST
# 35       312  AFP  DEBAR MOUNTAIN WILD FOREST
# 37       314  AFP  DEBAR MOUNTAIN WILD FOREST
# 38       317  AFP  DEBAR MOUNTAIN WILD FOREST
#
#                                       NAME       ASSET ATV FOOT HORSE BIKE XC  \
# 31                 MAIN BRANCH CANOE CARRY  FOOT TRAIL   N    M     N    N  N
# 34                  CAMP SITE ACCESS TRAIL  FOOT TRAIL   N    Y     N    N  N
# 35                            ACCESS TRAIL  FOOT TRAIL   N    Y     N    N  N
# 37                 EAST BRANCH CANOE CARRY  FOOT TRAIL   N    Y     N    N  Y
# 38  RAINBOW LAKE TO JONES POND CANOE CARRY  FOOT TRAIL   N    Y     N    N  Y
#
#     ... MAPPWD DESCRIP ROAD_CLASS     UPDATED REGION     OFFICE MARKER  \
# 31  ...      N    None         RT  2006-08-24      5  RAY BROOK   None
# 34  ...      N    None         RT  2011-04-19      5  RAY BROOK   None
# ...

# %%
#Polygon(County boundaries)
counties=gpd.read_file('/content/NY_county_boundaries.shp')
counties.head()
# Out:
#   STATE COUNTY          NAME LSAD LSAD_TRANS  OID_ COUNTY_FIP  POP2000  \
# 0    36    089  St. Lawrence   06     County    44        089   111931
# 1    36    019       Clinton   06     County     9        019    79894
# 2    36    033      Franklin   06     County    16        033    51134
# 3    36    031         Essex   06     County    15        031    38851
# 4    36    045     Jefferson   06     County    22        045   111738
#
#     WHITE  BLACK  ...  FHH_MINORC  FAMILIES  AV_FAM_SZ  HSE_UNITS  URBAN  \
# 0  105782   2664  ...        2773     26939          3      49721  16085
# 1   74562   2863  ...        1951     19261          3      33091  12161
# 2   42970   3389  ...        1312     11805          3      23936   7409
# 3   36848   1092  ...         810      9832          3      23115   4288
# 4   99118   6517  ...        2815     28142          3      54070  20947
#
#    RURAL  VACANT  OWNER_OCC  RENTER_OCC  \
# 0  33636    9215      28606       11900
# ...

# %%
#Combining together all 4 dataframes to form a map
ax=counties.plot(figsize=(10,10),color='none',edgecolor='black',zorder=3)

wild_lands.plot(color='green',ax=ax)
campsites.plot(color='red',markersize=2,ax=ax)
trails.plot(color='blue',markersize=1,ax=ax)
# Out:
# <Axes: >
