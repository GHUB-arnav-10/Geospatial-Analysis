# %% [markdown]
# <a href="https://colab.research.google.com/github/GHUB-arnav-10/Geospatial-Analysis/blob/main/Geocoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="me")
location = geolocator.geocode("India Gate")

print(location.point)
print(location.address)
# Out:
# 28 36m 46.5595s N, 77 13m 46.1742s E
# India Gate, Shahjahan Road, Pandara Park, Chanakya Puri Tehsil, New Delhi, Delhi, 020626, India

# %%
point=location.point
print("Latitude:", point.latitude)
print("Longitude:", point.longitude)
# Out:
# Latitude: 28.6129332
# Longitude: 77.22949282049879

# %%
import pandas as pd
universities = pd.read_csv("/content/top_universities.csv")
universities.head()
# Out:
#                       Name
# 0     University of Oxford
# 1  University of Cambridge
# 2  Imperial College London
# 3               ETH Zurich
# 4                      UCL

# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

universities[['Latitude', 'Longitude']] = universities.apply(lambda x: my_geocoder(x['Name']), axis=1)

print("{}% of addresses were geocoded!".format(
    (1 - sum(np.isnan(universities["Latitude"])) / len(universities)) * 100))
universities = universities.loc[~np.isnan(universities["Latitude"])]
universities = gpd.GeoDataFrame(
    universities, geometry=gpd.points_from_xy(universities.Longitude, universities.Latitude))
universities.crs = {'init': 'epsg:4326'}
universities.head()
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Durham+University&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=University+of+Exeter&format=json&limit=1
# 100.0% of addresses were geocoded!
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#                       Name   Latitude  Longitude                   geometry
# 0     University of Oxford  51.758708  -1.255668  POINT (-1.25567 51.75871)
# 1  University of Cambridge  52.210946   0.092005   POINT (0.09200 52.21095)
# 2  Imperial College London  51.498959  -0.175641  POINT (-0.17564 51.49896)
# 3               ETH Zurich  47.562772   7.580947   POINT (7.58095 47.56277)
# 4                      UCL  51.521785  -0.135151  POINT (-0.13515 51.52179)

# %%
import folium
from folium import Marker
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

for idx, row in universities.iterrows():
    Marker([row['Latitude'], row['Longitude']], popup=row['Name']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dc2c14ce112826e372763672f9d61d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dc2c14ce112826e372763672f9d61d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dc2c14ce112826e372763672f9d61d8 = L.map(
#                 &quot;map_4dc2c14ce112826e372763672f9d61d8&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7fe09b84cebec83b95f54ad0e7768cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#             var marker_fef774a68d50aae8709005923fce7fc5 = L.marker(
#                 [51.75870755, -1.2556684826092037],
#                 {}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#         var popup_9b9627081a9e78c5763d12f5b55b65a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a68c8b95eff7c0f3dd4d39753ed393e3 = $(`&lt;div id=&quot;html_a68c8b95eff7c0f3dd4d39753ed393e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_9b9627081a9e78c5763d12f5b55b65a4.setContent(html_a68c8b95eff7c0f3dd4d39753ed393e3);
#
#
#
#         marker_fef774a68d50aae8709005923fce7fc5.bindPopup(popup_9b9627081a9e78c5763d12f5b55b65a4)
#         ;
#
#
#
#
#             var marker_1d0e5e7436cd51e7f424a992727ebbeb = L.marker(
#                 [52.210945550000005, 0.09200497637871279],
#                 {}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#         var popup_f2a280374f8702d44d45bc405b59a0ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94c9ccadced55bb3ff6a8649bfe3cc45 = $(`&lt;div id=&quot;html_94c9ccadced55bb3ff6a8649bfe3cc45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_f2a280374f8702d44d45bc405b59a0ff.setContent(html_94c9ccadced55bb3ff6a8649bfe3cc45);
#
#
#
#         marker_1d0e5e7436cd51e7f424a992727ebbeb.bindPopup(popup_f2a280374f8702d44d45bc405b59a0ff)
#         ;
#
#
#
#
#             var marker_7cb5ac296927f990102cc1012f80adac = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#         var popup_073f9debfcd16b818bc0ef149aafb722 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdb0fc91ff62aac553d51d2cdb191663 = $(`&lt;div id=&quot;html_cdb0fc91ff62aac553d51d2cdb191663&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_073f9debfcd16b818bc0ef149aafb722.setContent(html_cdb0fc91ff62aac553d51d2cdb191663);
#
#
#
#         marker_7cb5ac296927f990102cc1012f80adac.bindPopup(popup_073f9debfcd16b818bc0ef149aafb722)
#         ;
#
#
#
#
#             var marker_a1209d39c85eda115b9fd58c0928174d = L.marker(
#                 [47.56277165, 7.580947334069263],
#                 {}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#         var popup_56aa19216dc981b12c2bc0678880f0ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82670dd8fd2eba5f2882549f6a875919 = $(`&lt;div id=&quot;html_82670dd8fd2eba5f2882549f6a875919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_56aa19216dc981b12c2bc0678880f0ea.setContent(html_82670dd8fd2eba5f2882549f6a875919);
#
#
#
#         marker_a1209d39c85eda115b9fd58c0928174d.bindPopup(popup_56aa19216dc981b12c2bc0678880f0ea)
#         ;
#
#
#
#
#             var marker_81221c0876ea3a99ec449f2a7521c9a3 = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_4dc2c14ce112826e372763672f9d61d8);
#
#
#         var popup_9fa6ea408b088e5bda24116bb4d13e1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_034583e8898e841d771bda401f5711da = $(`&lt;div id=&quot;html_034583e8898e841d771bda401f5711da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_9fa6ea408b088e5bda24116bb4d13e1d.setContent(html_034583e8898e841d771bda401f5711da);
#
#
#
#         marker_81221c0876ea3a99ec449f2a7521c9a3.bindPopup(popup_9fa6ea408b088e5bda24116bb4d13e1d)
#         ;
#
#
#
#
#             var marker_b1735a63074d319c04f89244a63dd5d4

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
europe = world.loc[world.continent == 'Europe'].reset_index(drop=True)

europe_stats = europe[["name", "pop_est", "gdp_md_est"]]
europe_boundaries = europe[["name", "geometry"]]
europe_boundaries.head()
# Out:
# <ipython-input-14-89e6ca10678a>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       name                                           geometry
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...

# %%
europe_stats.head()
# Out:
#       name      pop_est  gdp_md_est
# 0   Russia  144373535.0     1699876
# 1   Norway    5347896.0      403336
# 2   France   67059887.0     2715518
# 3   Sweden   10285453.0      530883
# 4  Belarus    9466856.0       63080

# %%
europe = europe_boundaries.merge(europe_stats, on="name")
europe.head()
# Out:
#       name                                           geometry      pop_est  \
# 0   Russia  MULTIPOLYGON (((180.00000 71.51571, 180.00000 ...  144373535.0
# 1   Norway  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...    5347896.0
# 2   France  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...   67059887.0
# 3   Sweden  POLYGON ((11.02737 58.85615, 11.46827 59.43239...   10285453.0
# 4  Belarus  POLYGON ((28.17671 56.16913, 29.22951 55.91834...    9466856.0
#
#    gdp_md_est
# 0     1699876
# 1      403336
# 2     2715518
# 3      530883
# 4       63080

# %%
european_universities = gpd.sjoin(universities, europe)


print("We located {} universities.".format(len(universities)))
print("Only {} of the universities were located in Europe (in {} different countries).".format(
    len(european_universities), len(european_universities.name.unique())))

european_universities.head()
# Out:
# We located 90 universities.
# Only 87 of the universities were located in Europe (in 15 different countries).
# <ipython-input-17-64532861afad>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   european_universities = gpd.sjoin(universities, europe)
#                                                Name   Latitude  Longitude  \
# 0                              University of Oxford  51.758708  -1.255668
# 1                           University of Cambridge  52.210946   0.092005
# 2                           Imperial College London  51.498959  -0.175641
# 4                                               UCL  51.521785  -0.135151
# 5  London School of Economics and Political Science  51.514261  -0.116734
#
#                     geometry  index_right            name     pop_est  \
# 0  POINT (-1.25567 51.75871)           28  United Kingdom  66834405.0
# 1   POINT (0.09200 52.21095)           28  United Kingdom  66834405.0
# 2  POINT (-0.17564 51.49896)           28  United Kingdom  66834405.0
# 4  POINT (-0.13515 51.52179)           28  United Kingdom  66834405.0
# 5  POINT (-0.11673 51.51426)           28  United Kingdom  66834405.0
#
#    gdp_md_est
# 0     2829108
# 1     2829108
# 2     2829108
# 4     2829108
# 5     2829108

# %%
asia = world.loc[world.continent == 'Asia'].reset_index(drop=True)

asia_stats = asia[["name", "pop_est", "gdp_md_est"]]
asia_boundaries = asia[["name", "geometry"]]
asia_boundaries.head()
# Out:
#           name                                           geometry
# 0   Kazakhstan  POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# 1   Uzbekistan  POLYGON ((55.96819 41.30864, 55.92892 44.99586...
# 2    Indonesia  MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...
# 3  Timor-Leste  POLYGON ((124.96868 -8.89279, 125.08625 -8.656...
# 4       Israel  POLYGON ((35.71992 32.70919, 35.54567 32.39399...

# %%
asia_stats.head()
# Out:
#           name      pop_est  gdp_md_est
# 0   Kazakhstan   18513930.0      181665
# 1   Uzbekistan   33580650.0       57921
# 2    Indonesia  270625568.0     1119190
# 3  Timor-Leste    1293119.0        2017
# 4       Israel    9053300.0      394652

# %%
asia = asia_boundaries.merge(asia_stats, on="name")
asia.head()
# Out:
#           name                                           geometry  \
# 0   Kazakhstan  POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# 1   Uzbekistan  POLYGON ((55.96819 41.30864, 55.92892 44.99586...
# 2    Indonesia  MULTIPOLYGON (((141.00021 -2.60015, 141.01706 ...
# 3  Timor-Leste  POLYGON ((124.96868 -8.89279, 125.08625 -8.656...
# 4       Israel  POLYGON ((35.71992 32.70919, 35.54567 32.39399...
#
#        pop_est  gdp_md_est
# 0   18513930.0      181665
# 1   33580650.0       57921
# 2  270625568.0     1119190
# 3    1293119.0        2017
# 4    9053300.0      394652

# %%
asian_universities = gpd.sjoin(universities, asia)


print("We located {} universities.".format(len(universities)))
print("Only {} of the universities were located in Asia (in {} different countries).".format(
    len(asian_universities), len(asian_universities.name.unique())))

asian_universities.head()
# Out:
# We located 90 universities.
# Only 1 of the universities were located in Asia (in 1 different countries).
# <ipython-input-22-c149c914c9eb>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   asian_universities = gpd.sjoin(universities, asia)
#                          Name  Latitude   Longitude  \
# 45  University of Southampton  1.429917  103.612177
#
#                      geometry  index_right      name     pop_est  gdp_md_est
# 45  POINT (103.61218 1.42992)           40  Malaysia  31949777.0      364681

# %%
NorthAmerica = world.loc[world.continent == 'North America'].reset_index(drop=True)

na_stats = NorthAmerica[["name", "pop_est", "gdp_md_est"]]
na_boundaries = NorthAmerica[["name", "geometry"]]
na_boundaries.head()
# Out:
#                        name                                           geometry
# 0                    Canada  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 1  United States of America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# 2                     Haiti  POLYGON ((-71.71236 19.71446, -71.62487 19.169...
# 3            Dominican Rep.  POLYGON ((-71.70830 18.04500, -71.68774 18.316...
# 4                   Bahamas  MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...

# %%
na_stats.head()
# Out:
#                        name      pop_est  gdp_md_est
# 0                    Canada   37589262.0     1736425
# 1  United States of America  328239523.0    21433226
# 2                     Haiti   11263077.0       14332
# 3            Dominican Rep.   10738958.0       88941
# 4                   Bahamas     389482.0       13578

# %%
na = na_boundaries.merge(na_stats, on="name")
na.head()
# Out:
#                        name  \
# 0                    Canada
# 1  United States of America
# 2                     Haiti
# 3            Dominican Rep.
# 4                   Bahamas
#
#                                             geometry      pop_est  gdp_md_est
# 0  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...   37589262.0     1736425
# 1  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  328239523.0    21433226
# 2  POLYGON ((-71.71236 19.71446, -71.62487 19.169...   11263077.0       14332
# 3  POLYGON ((-71.70830 18.04500, -71.68774 18.316...   10738958.0       88941
# 4  MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...     389482.0       13578

# %%
na_universities = gpd.sjoin(universities, na)


print("We located {} universities.".format(len(universities)))
print("Only {} of the universities were located in North America (in {} different countries).".format(
    len(na_universities), len(na_universities.name.unique())))

na_universities.head()
# Out:
# We located 90 universities.
# Only 1 of the universities were located in North America (in 1 different countries).
# <ipython-input-26-05bbf0465828>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   na_universities = gpd.sjoin(universities, na)
#                     Name   Latitude  Longitude                    geometry  \
# 57  University of Geneva  41.799306 -80.961667  POINT (-80.96167 41.79931)
#
#     index_right                      name      pop_est  gdp_md_est
# 57            1  United States of America  328239523.0    21433226
